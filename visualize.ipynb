# %%
import matplotlib.pyplot as plt
import numpy as np

with open("/home/tanluuuuuuu/Desktop/luunvt/oriented_object_detection/mmrotate/work_dirs/roi_trans_r50_fpn_1x_dota_le90_exam_distributions/iou.bin", 'r') as f:
  for line in f:
    print(line)
# Out:
# 0.18151788413524628, 0.1707693487405777, 0.17042632400989532, 0.16855104267597198, 0.16839748620986938, 0.1624971479177475, 0.15877316892147064, 0.15622831881046295, 0.1561933308839798, 0.15619327127933502, 0.1558387726545334, 0.15515562891960144, 0.15444448590278625, 0.15407061576843262, 0.15282195806503296, 0.15253318846225739, 0.15247857570648193, 0.1503974050283432, 0.14913184940814972, 0.1489945352077484, 0.1489274948835373, 0.14842472970485687, 0.1478160321712494, 0.14635905623435974, 0.14622163772583008, 0.1462065875530243, 0.14608637988567352, 0.14504122734069824, 0.14476563036441803, 0.1444585621356964, 0.14399197697639465, 0.14387120306491852, 0.14264719188213348, 0.1423720270395279, 0.142347052693367, 0.1420394629240036, 0.14172500371932983, 0.14168737828731537, 0.14162835478782654, 0.14136479794979095, 0.1412685215473175
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

f = open("/home/tanluuuuuuu/Desktop/luunvt/oriented_object_detection/mmrotate/work_dirs/dynamic_roi_trans_r50_fpn_1x_dota_le90_iou75_beta10_iter100_head1_v2/check_num_pos_1000e_top150_btop20.txt", 'r')
lines = [float(x.strip()) for x in f.readlines()]
img_pos_sample = [x for i, x in enumerate(lines) if i % 2 == 0]
epochs = np.arange(1, len(img_pos_sample) + 1)
plt.plot(epochs, img_pos_sample, 'g')

# %%
import matplotlib.pyplot as plt
import numpy as np

f = open("/home/tanluuuuuuu/Desktop/luunvt/oriented_object_detection/mmrotate/work_dirs/dynamic_roi_trans_r50_fpn_1x_dota_le90_iou75_beta10_iter100_head1_v2/check_num_pos_1000e_top150_btop20.txt", 'r')
lines = [int(x.strip()) for x in f.readlines()]
img_pos_sample0 = [x for i, x in enumerate(lines) if i % 2 == 0]
# mean_pos_sample = [np.mean(sum_pos_sample[i:i+5]) for i in range(len(sum_pos_sample) // 5)]
# print(sum_pos_sample)
# print(len(sum_pos_sample))
epochs = np.arange(1, len(img_pos_sample0) + 1)
plt.plot(epochs, img_pos_sample0, 'g')

f = open("/home/tanluuuuuuu/Desktop/luunvt/oriented_object_detection/mmrotate/work_dirs/dynamic_roi_trans_r50_fpn_1x_dota_le90_iou75_beta10_iter100_head1_v2/check_num_pos_1000e_top150.txt", 'r')
lines = [int(x.strip()) for x in f.readlines()]
img_pos_sample0 = [x for i, x in enumerate(lines) if i % 2 == 0]
# plt.plot(epochs, img_pos_sample1)
# print(min(img_pos_sample0))
# print(max(img_pos_sample0))
plt.plot(epochs, img_pos_sample0, 'b')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import time
x, y = [], []
with open("/home/tanluuuuuuu/Desktop/luunvt/oriented_object_detection/mmrotate/work_dirs/oriented_rcnn_r50_fpn_1x_dota_le90_examine/check_xywha.txt", 'r') as f:
  for line in f:
    x.append(float(line.strip().split("\t")[0]))
    y.append(float(line.strip().split("\t")[1]))

for i in range(0, len(x), 4096):
  plt.clf()
  plt.scatter(x[i:i+4096], y[i:i+4096], s=1)
  plt.savefig(f"{str(i)}.png")

# %%
import matplotlib.pyplot as plt
import numpy as np
x, y = [], []
with open("/home/tanluuuuuuu/Desktop/luunvt/oriented_object_detection/mmrotate/work_dirs/oriented_rcnn_r50_fpn_1x_dota_le90_examine/check_xywha.txt", 'r') as f:
  for line in f:
    x.append(float(line.strip().split("\t")[0]))
    y.append(float(line.strip().split("\t")[1]))

print(len(x))
print(len(y))
plt.scatter(x[4096:4096*2], y[4096:4096*2], s=1)
# Out:
# 49152
# 49152
