# %%
import matplotlib.pyplot as plt
import numpy as np

f = open("/home/tanluuuuuuu/Desktop/luunvt/oriented_object_detection/mmrotate/work_dirs/oriented_rcnn_r50_fpn_1x_dota_le90_examine/check_num_pos.txt", 'r')
lines = [int(x.strip()) for x in f.readlines()]
img_pos_sample0 = [x for i, x in enumerate(lines) if i % 8 == 0]
img_pos_sample1 = [x for i, x in enumerate(lines) if i % 8 == 1]
sum_pos_sample = [sum(lines[i:i+8]) for i in range(len(lines) // 8)]
# mean_pos_sample = [np.mean(sum_pos_sample[i:i+5]) for i in range(len(sum_pos_sample) // 5)]
# print(sum_pos_sample)
# print(len(sum_pos_sample))
epochs = np.arange(1, len(sum_pos_sample) + 1)
# plt.plot(epochs, img_pos_sample1)
# print(min(img_pos_sample0))
# print(max(img_pos_sample0))
plt.plot(epochs, sum_pos_sample, 'g')

# %%
import matplotlib.pyplot as plt
import numpy as np

f = open("/home/tanluuuuuuu/Desktop/luunvt/oriented_object_detection/mmrotate/work_dirs/roi_trans_r50_fpn_1x_dota_le90_examine/check_num_pos.txt", 'r')
lines = [int(x.strip()) for x in f.readlines()]
img_pos_sample0 = [x for i, x in enumerate(lines) if i % 8 == 0]
img_pos_sample1 = [x for i, x in enumerate(lines) if i % 8 == 1]
sum_pos_sample = [sum(lines[i:i+8]) for i in range(len(lines) // 8)]
# mean_pos_sample = [np.mean(sum_pos_sample[i:i+5]) for i in range(len(sum_pos_sample) // 5)]
# print(sum_pos_sample)
# print(len(sum_pos_sample))
epochs = np.arange(1, len(sum_pos_sample) + 1)
# plt.plot(epochs, img_pos_sample1)
# print(min(img_pos_sample0))
# print(max(img_pos_sample0))
plt.plot(epochs, sum_pos_sample, 'g')
